# %%
# Import Library
import pandas as pd

# %%
# Data Collection
dataset=pd.read_csv("Insurance-Data.csv")

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
# Input and Output Split
independent=dataset[['age', 'bmi', 'children','sex_male','smoker_yes']]

# %%
dependent=dataset[['charges']]

# %%
# In Regression GridSearchCv no need of split train and test set
# Using GridSearchCV and Creating Model
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV
param_grid = {'criterion': ['squared_error', 'absolute_error', 'friedman_mse', 'poisson'],
                'splitter':['best', 'random']}
grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit = True, verbose = 3, n_jobs = -1) 
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
y_pred=grid.predict(independent)
from sklearn.metrics import r2_score
r_score=r2_score(y_pred,dependent)

# %%
# Print best parameter after tuning
re=grid.cv_results_
print("R_score value for best parameter{}:".format(grid.best_params_), r_score)
# Out:
# R_score value for best parameter{'criterion': 'absolute_error', 'splitter': 'best'}: 0.9986653772918882

# %%
# Here rank test score 1 is the best parameter
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.006604      0.002209         0.002691        0.000889
# 1       0.003337      0.001352         0.001416        0.000738
# 2       0.026953      0.001624         0.001802        0.000854
# 3       0.019913      0.004387         0.001450        0.000795
# 4       0.003620      0.000862         0.001289        0.000660
# 5       0.003352      0.001783         0.001430        0.000976
# 6       0.005910      0.002600         0.001034        0.000064
# 7       0.003343      0.000611         0.001250        0.000436
#
#   param_criterion param_splitter  \
# 0   squared_error           best
# 1   squared_error         random
# 2  absolute_error           best
# 3  absolute_error         random
# 4    friedman_mse           best
# 5    friedman_mse         random
# 6         poisson           best
# 7         poisson         random
#
#                                               params  split0_test_score  \
# 0  {'criterion': 'squared_error', 'splitter': 'be...           0.721573
# 1  {'criterion': 'squared_error', 'splitter': 'ra...           0.718687
# 2  {'criterion': 'absolute_error', 'splitter': 'b...           0.719809
# 3  {'criterion': 'absolute_error', 'splitter': 'r...           0.709159
# 4  {'criterion': 'friedman_mse', 'splitter': 'best'}           0.710768
# 5  {'criterion': 'friedman_mse', 'splitter': 'ran...           0.700984
# 6       {'criterion': 'poisson', 'splitter': 'best'}           0.737780
# 7     {'criterion': 'poisson', 'splitter': 'random'}           0.708152
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.645753           0.738283           0.703164           0.664668
# 1           0.705529           0.653165           0.729855           0.741132
# 2           0.668575           0.723804           0.717484           0.755898
# 3           0.601823           0.718220           0.720707           0.767540
# 4           0.642979           0.731290           0.735317           0.672822
# 5           0.656411           0.738736           0.734733           0.741549
# 6           0.664714           0.733021           0.716889           0.693372
# 7           0.596937           0.613311           0.768959           0.767411
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.694688        0.034615                7
# 1         0.709673        0.030622                3
# 2         0.717114        0.027973                1
# 3         0.703490        0.054743                5
# 4         0.698635        0.035561                6
# 5         0.714483        0.032513                2
# 6         0.709155        0.027103                4
# 7         0.690954        0.073612                8

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 32
# BMI: 23
# Children: 1
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 1

# %%
Future_prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_prediction={}".format(Future_prediction))
# Out:
# Future_prediction=[17496.306]
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
# Save the Model
import pickle
filename="8.Final-Model-Grid-DecisionTree.sav"

# %%
pickle.dump(grid,open(filename,'wb'))
